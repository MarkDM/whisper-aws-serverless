# %%
# %pip install git+https://github.com/stlukey/whispercpp.py
# Out:
# Collecting git+https://github.com/stlukey/whispercpp.py
#   Cloning https://github.com/stlukey/whispercpp.py to c:\users\marcos\appdata\local\temp\pip-req-build-ti92xt6b
#   Resolved https://github.com/stlukey/whispercpp.py to commit 7af678159c29edb3bc2a51a72665073d58f2352f
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\marcos\anaconda3\lib\site-packages (from whispercpp==1.0) (1.26.4)
# Collecting ffmpeg-python (from whispercpp==1.0)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: requests in c:\users\marcos\anaconda3\lib\site-packages (from whispercpp==1.0) (2.32.2)
# Collecting future (from ffmpeg-python->whispercpp==1.0)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marcos\anaconda3\lib\site-packages (from requests->whispercpp==1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marcos\anaconda3\lib\site-packages (from requests->whispercpp==1.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marcos\anaconda3\lib\site-packages (from requests->whispercpp==1.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marcos\anaconda3\lib\site-packages (from requests->whispercpp==1.0) (2024.6.2)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
#    ---------------------------------------- 0.0/491.3 kB ? eta -:--:--
#    ----- ---------------------------------- 71.7/491.3 kB 1.3 MB/s eta 0:00:01
#    -------------------------------- ------- 399.4/491.3 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 491.3/491.3 kB 3.8 MB/s eta 0:00:00
# Building wheels for collected packages: whispercpp
#   Building wheel for whispercpp (pyproject.toml): started
#   Building wheel for whispercpp (pyproject.toml): finished with status 'done'
#   Created wheel for whispercpp: filename=whispercpp-1.0-cp312-cp312-win_amd64.whl size=183371 sha256=40deb155b0beabf6a9a87e161a79b9237f503777daf78c7fad9562b3e3555421
#   Stored in directory: C:\Users\Marcos\AppData\Local\Temp\pip-ephem-wheel-cache-47ez0vnm\wheels\b3\90\e4\2e74666ccedc3676bdce322b43c71fb6a27c1f193e87ae6ad6
# Successfully built whispercpp
# Installing collected packages: future, ffmpeg-python, whispercpp
# Successfully installed ffmpeg-python-0.2.0 future-1.0.0 whispercpp-1.0
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/stlukey/whispercpp.py 'C:\Users\Marcos\AppData\Local\Temp\pip-req-build-ti92xt6b'
#   Running command git submodule update --init --recursive -q

# %%
from whispercpp import Whisper

w = Whisper('tiny')

result = w.transcribe("./jfk.wav")
text = w.extract_text(result)
text
# Out:
# Loading data..
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File whispercpp.pyx:54, in whispercpp.load_audio()
#
# File c:\Users\Marcos\anaconda3\Lib\site-packages\ffmpeg\_run.py:313, in run(stream_spec, cmd, capture_stdout, capture_stderr, input, quiet, overwrite_output)
#     299 """Invoke ffmpeg for the supplied node graph.
#     300
#     301 Args:
#    (...)
#     311 Returns: (out, err) tuple containing captured stdout and stderr data.
#     312 """
# --> 313 process = run_async(
#     314     stream_spec,
#     315     cmd,
#     316     pipe_stdin=input is not None,
#     317     pipe_stdout=capture_stdout,
#     318     pipe_stderr=capture_stderr,
#     319     quiet=quiet,
#     320     overwrite_output=overwrite_output,
#     321 )
#     322 out, err = process.communicate(input)
#
# File c:\Users\Marcos\anaconda3\Lib\site-packages\ffmpeg\_run.py:284, in run_async(stream_spec, cmd, pipe_stdin, pipe_stdout, pipe_stderr, quiet, overwrite_output)
#     283 stderr_stream = subprocess.PIPE if pipe_stderr or quiet else None
# --> 284 return subprocess.Popen(
#     285     args, stdin=stdin_stream, stdout=stdout_stream, stderr=stderr_stream
#     286 )
#
# File c:\Users\Marcos\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File c:\Users\Marcos\anaconda3\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] O sistema não pode encontrar o arquivo especificado
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 5
#       1 from whispercpp import Whisper
#       3 w = Whisper('tiny')
# ----> 5 result = w.transcribe("./jfk.wav")
#       6 text = w.extract_text(result)
#       7 text
#
# File whispercpp.pyx:112, in whispercpp.Whisper.transcribe()
#
# File whispercpp.pyx:61, in whispercpp.load_audio()
#
# RuntimeError: File './jfk.wav' not found
